# %%
import os
import re
import time
import json
import logging
import calendar
import datetime
import functools

import feedparser
from pytz import utc
from dateutil.parser import parse
import os
import re
import time
import json
import logging
import calendar
import datetime
import functools

import feedparser
from pytz import utc
from dateutil.parser import parse

try:
    from urllib2 import urlopen
    from urllib2 import HTTPError
except ImportError:
    from urllib.request import urlopen
    from urllib.error import HTTPError


# In[3]:

FEED_URL = 'http://gdacs.org/rss.aspx?profile=ARCHIVE&from={}'
DISPLACED_RE = re.compile('.*(\d+) displaced')
DEPTH_RE = re.compile('.*Depth:(\d+\.\d+)km')


def dtconv(struct_time):
    dt = datetime.datetime(*struct_time[:7], tzinfo=utc)
    return calendar.timegm(dt.utctimetuple())


def dt_to_date(s):
    dt = parse(s)
    dt = dt.replace(hour=0, minute=0, second=0)
    return calendar.timegm(dt.utctimetuple())


def tsconv(s):
    dt = parse(s)
    return calendar.timegm(dt.utctimetuple())


def get_map(entry):
    try:
        return [l['href'] for l in entry.links if l['rel'] == 'enclosure'][0]
    except IndexError:
        return None


def url_to_filename(url):
    return url.split('/')[-1]


def fetch_asset(url, outdir):
    print "fetching asset from %s" %url
    logging.debug('Fetchings asset from %s', url)
    filename = url_to_filename(url)
    outpath = os.path.join(outdir, filename)
    try:
        with open(outpath, 'w') as f:
            f.write(urlopen(url).read())
    except HTTPError:
        return ''
    return filename


def get_assets(data, outdir):
    for k, url in data.items():
        if url:
            data[k] = fetch_asset(url, outdir)


def gdacs_data(fn):
    @functools.wraps(fn)
    def wrapper(entry, outdir):
        logging.debug('Formatting entry %s', entry.gdacs_eventid)
        data = {
            'id': entry.gdacs_eventid,
            'type': entry.gdacs_eventtype,
            'name': entry.gdacs_eventname,
            'location': entry.gdacs_country or None,
            'alert_level': entry.gdacs_alertlevel.lower(),
            'updated': dtconv(entry.updated_parsed),
            'summary': entry.summary,
            'maps': {
                'thumb': get_map(entry),
                'details': entry.gdacs_mapimage or None,
            }
        }
        get_assets(data['maps'], outdir)
        data['info'] = fn(entry)
        return data
    return wrapper


@gdacs_data
def format_earthquake(entry):
    try:
        depth = float(DEPTH_RE.match(entry.summary).group(1))
    except (AttributeError, ValueError, TypeError):
        depth = None
    return {
        'severity': entry.gdacs_severity['value'],
        'affected_population': entry.gdacs_population['value'],
        'time': tsconv(entry.gdacs_fromdate),
    }


@gdacs_data
def format_flood(entry):
    return {
        'severity': entry.gdacs_severity['value'],
        'affected_population': entry.gdacs_population['value'],
        'duration': {
            'from': dt_to_date(entry.gdacs_fromdate),
            'to': dt_to_date(entry.gdacs_todate),
        },
    }


@gdacs_data
def format_tcyclone(entry):
    try:
        displaced = int(DISPLACED_RE.match(entry.summary).group(1))
    except (AttributeError, ValueError, TypeError):
        displaced = 0
    return {
        'severity': '{} {}'.format(entry.gdacs_severity['value'],
                                   entry.gdacs_severity['unit']),
        'affected_population': displaced,
        'deaths': entry.gdacs_population['value'],
        'duration': {
            'from': dt_to_date(entry.gdacs_fromdate),
            'to': dt_to_date(entry.gdacs_todate),
        },
    }


FORMATTERS = {
    'EQ': format_earthquake,
    'FL': format_flood,
    'TC': format_tcyclone,
}


def get_feed_url():
    dt = datetime.datetime.utcnow() - datetime.timedelta(days=30)
    return FEED_URL.format(dt.strftime('%Y-%m-%d'))


def get_feed():
    logging.debug('Obtaining feed')
    url = get_feed_url()
    data = feedparser.parse(url)
    return data.entries


def formatted_entries(entries, outdir):
    logging.debug('Formatting entries')
    return [FORMATTERS[e.gdacs_eventtype](e, outdir) for e in entries]


def write_json(outfile, entries):
    with open(outfile, 'w') as f:
        json.dump(entries, f, indent=2)


def main():
    import argparse
    parser = argparse.ArgumentParser(description='Convert GDACS data to JSON')
    parser.add_argument('--output', '-o', metavar='PATH', default='gdacs.json',
                        help='Output JSON file path')
    parser.add_argument('--verbose', '-V', action='store_true', help='output '
                        'debug messages')
    args = parser.parse_args()

    if args.verbose:
        logging.getLogger().setLevel(logging.DEBUG)

    entries = get_feed()
    outdir = os.path.dirname(args.output)
    write_json(args.output, formatted_entries(entries, outdir))


if __name__ == '__main__':
    main()
# Out:
# usage: ipykernel_launcher.py [-h] [--output PATH] [--verbose]
# ipykernel_launcher.py: error: unrecognized arguments: -f /Users/michael/Library/Jupyter/runtime/kernel-71ec0206-6f32-49b4-8793-9d8c9e3e7508.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
who = 'http://www.who.int/feeds/entity/hac/en/rss.xml'
gdacs_eq_24h = 'http://www.gdacs.org/xml/rss_eq_24h.xml'
gdacs_eq_gt55_48h = 'http://www.gdacs.org/xml/rss_eq_48h_med.xml'
gdacs_all_24h = 'http://www.gdacs.org/xml/rss_24h.xml'
gdacs_all_7d = 'http://www.gdacs.org/xml/rss_7d.xml'
gdacs_ts_7d = 'http://www.gdacs.org/xml/rss_tc_7d.xml'
gdacs_ts_3m = 'http://www.gdacs.org/xml/rss_tc_3m.xml'
gdacs_fl_7d = 'http://www.gdacs.org/xml/rss_fl_7d.xml'
gdacs_fl_3m = 'http://www.gdacs.org/xml/rss_fl_3m.xml'
reliefweb = 'https://reliefweb.int/disasters/rss.xml'
reliefweb_map = 'https://reliefweb.int/maps/rss.xml'
dost_pagasa_sl = 'https://www1.pagasa.dost.gov.ph/prsdcodes/rss/prsd/slforecast.xml'

# %%
outfol = '/Users/michael/Desktop/out/'
fn = fetch_asset(gdacs_all_24h, outfol)
feed = outfol + fn
print feed
# Out:
# fetching asset from http://www.gdacs.org/xml/rss_24h.xml
# /Users/michael/Desktop/out/rss_24h.xml

# %%
import xml.dom.minidom
import xml.etree.ElementTree as ET
xml = xml.dom.minidom.parse(feed) # or xml.dom.minidom.parseString(xml_string)
xml_string = xml.toprettyxml()
print xml_string
# Out:
# <?xml version="1.0" ?>
# <rss version="2.0" xmlns:asgard="http://asgard.jrc.it" xmlns:atom="http://www.w3.org/2005/Atom" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:gdacs="http://www.gdacs.org" xmlns:geo="http://www.w3.org/2003/01/geo/wgs84_pos#" xmlns:georss="http://www.georss.org/georss" xmlns:glide="http://glidenumber.net">
#
#
# 	<channel>
#
#
# 		<title>GDACS RSS information</title>
#
#
# 		<link>http://www.gdacs.org/</link>
#
#
# 		<description>Near real-time alerts about natural disaster with a potential humanitarian impact</description>
#
#
# 		<managingEditor>stefano.paris@ext.ec.europa.eu</managingEditor>
#
#
# 		<!--Records number 19-->
#
#
# 		<!--Start 9/14/2018 4:16:27 PM-->
#
#
# 		<!--=Start 9/14/2018 4:16:27 PM-->
#
#
# 		<webMaster>stefano.paris@ext.ec.europa.eu</webMaster>
#
#
# 		<pubDate>Fri, 14 Sep 2018 14:16:27 GMT</pubDate>
#
#
# 		<atom:link href="http://www.gdacs.org/xml/rss_24h.xml" rel="self" type="application/rss+xml"/>
#
#
# 		<item>
#
#
# 			<title>Green earthquake alert (Magnitude 5.4M, Depth:120.99km) in Peru 14/09/2018 11:20 UTC, 1050000 people within 100km.</title>
#
#
# 			<description>On 9/14/2018 11:20:02 AM, an earthquake occurred in Peru potentially affecting 1050000 people within 100km. The earthquake had Magnitude 5.4M, Depth:120.99km.</description>
#
#
# 			<enclosure length="1" type="image/png" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228272_1.png"/>
#
#
# 			<gdacs:temporary>false</gdacs:temporary>
#
#
# 			<link>http://www.gdacs.org/report.aspx?eventtype=EQ&amp;eventid=1156643</link>
#
#
# 			<pubDate>Fri, 14 Sep 2018 11:20:02 GMT</pubDate>
#
#
# 			<gdacs:fromdate>Fri, 14 Sep 2018 11:20:02 GMT</gdacs:fromdate>
#
#
# 			<gdacs:todate>Fri, 14 Sep 2018 11:20:02 GMT</gdacs:todate>
#
#
# 			<gdacs:year>2018</gdacs:year>
#
#
# 			<dc:subject>EQ1</dc:subject>
#
#
# 			<guid isPermaLink="false">EQ1156643</guid>
#
#
# 			<geo:Point>
#
#
# 				<geo:lat>-16.0473</geo:lat>
#
#
# 				<geo:long>-71.4991</geo:long>
#
#
# 			</geo:Point>
#
#
# 			<!--gdacs:bbox format = lonmin lonmax latmin latmax-->
#
#
# 			<gdacs:bbox>-75.4991 -67.4991 -20.0473 -12.0473</gdacs:bbox>
#
#
# 			<georss:point>-16.0473 -71.4991</georss:point>
#
#
# 			<gdacs:cap>http://www.gdacs.org/cap.aspx?eventtype=EQ&amp;eventid=1156643</gdacs:cap>
#
#
# 			<gdacs:version>1</gdacs:version>
#
#
# 			<gdacs:eventtype>EQ</gdacs:eventtype>
#
#
# 			<gdacs:alertlevel>Green</gdacs:alertlevel>
#
#
# 			<gdacs:alertscore>0.355322016411563</gdacs:alertscore>
#
#
# 			<gdacs:episodealertlevel>Green</gdacs:episodealertlevel>
#
#
# 			<gdacs:episodealertscore>1</gdacs:episodealertscore>
#
#
# 			<gdacs:eventname/>
#
#
# 			<gdacs:eventid>1156643</gdacs:eventid>
#
#
# 			<gdacs:episodeid>1228272</gdacs:episodeid>
#
#
# 			<gdacs:calculationtype>earthquakeonly</gdacs:calculationtype>
#
#
# 			<gdacs:severity unit="M" value="5.4">Magnitude 5.4M, Depth:120.99km</gdacs:severity>
#
#
# 			<gdacs:population unit="Population in 100km" value="1058015">1050000 people within 100km</gdacs:population>
#
#
# 			<gdacs:vulnerability value="1.78228028098837"/>
#
#
# 			<gdacs:iso3>PER</gdacs:iso3>
#
#
# 			<gdacs:country>Peru</gdacs:country>
#
#
# 			<gdacs:glide/>
#
#
# 			<gdacs:mapimage/>
#
#
# 			<gdacs:maplink/>
#
#
# 			<gdacs:gtsimage/>
#
#
# 			<gdacs:gtslink/>
#
#
# 			<gdacs:resources>
#
#
# 				<gdacs:resource id="overviewmap" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228272_2.png" version="0">
#
#
# 					<gdacs:title>Population density map</gdacs:title>
#
#
# 					<gdacs:description>The overview image impact with population density layer</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged. Population data from LandScan 2008.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="UNOSATmaps_country" source="" type="html" url="http://www.unitar.org/unosat/maps/PER" version="0">
#
#
# 					<gdacs:title>UNOSAT maps by country</gdacs:title>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="interactive_event_map" source="JRC" type="map" url="http://dma.gdacs.org/map?application=EARTHQUAKE&amp;eventid=1156643&amp;episodeid=1228272&amp;coordinate=-71.4991,-16.0473" version="0">
#
#
# 					<gdacs:title>Interactive earthquake event map</gdacs:title>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="impact_xml" source="JRC" type="xml" url="http://www.gdacs.org/gis/calculation/EQ1_WPS/-071\eq_-07150_-01605.xml" version="0">
#
#
# 					<gdacs:title>Affected population and infrastructure</gdacs:title>
#
#
# 					<gdacs:xslt>http://www.gdacs.org/xslt/asgard_summary.xslt&amp;pname=eventtype&amp;pvalue=EQ</gdacs:xslt>
#
#
# 					<gdacs:description>GIS analysis of the area affected by the earthquake</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="ocha_sitrep" source="OCHA" type="rss" url="http://www.reliefweb.int/updates?sl=environment-report_listing%252Ctaxonomy_index_tid_source-1503%252Ctaxonomy_index_tid_content_format-10%252Ctaxonomy_index_tid_disaster_type-4628" version="0">
#
#
# 					<gdacs:title>OCHA Situation Reports for Earthquakes</gdacs:title>
#
#
# 					<gdacs:description>List of most recent OCHA situation reports published on ReliefWeb</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="neic_report" source="NEIC" type="html" url="http://earthquake.usgs.gov/earthquakes/eventpage/us2000hekx#summary" version="0">
#
#
# 					<gdacs:title>USGS earthquake report</gdacs:title>
#
#
# 					<gdacs:description>Report of the USGS National Earthquake Information Center</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="geooffice" source="INGV" type="link" url="http://cnt.rm.ingv.it/" version="0">
#
#
# 					<gdacs:title>Istituto Nazionale di Geofisica e Vulcanologia</gdacs:title>
#
#
# 					<gdacs:description>Latest earthquakes recorded by the Italian National Earthquake Centre</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="thumbnailmap_cached" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228272_1.png" version="0">
#
#
# 					<gdacs:title>Overview thumbnail map</gdacs:title>
#
#
# 					<gdacs:description>The Impact thumbanil image</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="populationmap_cached" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228272_4.png" version="0">
#
#
# 					<gdacs:title>Population map close up</gdacs:title>
#
#
# 					<gdacs:description>The impact image</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="desinventar_disasters_profile" source="DesInventar" type="link" url="http:/www.desinventar.net/DesInventar/profiletab.jsp?countrycode=pe" version="0">
#
#
# 					<gdacs:title>Country disaster profile (DesInventar)</gdacs:title>
#
#
# 					<gdacs:description>This Country Profile shows a set of typical results known as &quot;Preliminary Analysis&quot; comming from the disaster database. Charts, Maps and tables below will provide you with a basic understanding of the effects of many types of natural disasters occurred in the region.</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="neic_json" source="NEIC" type="json" url="http://earthquake.usgs.gov/earthquakes/eventpage/us2000hekx.json" version="0">
#
#
# 					<gdacs:title>USGS NEIC Json Product Feed</gdacs:title>
#
#
# 					<gdacs:description>Json feed of products available on USGS NEIC website</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="impact_xml_old" source="JRC" type="xml" url="http://www.gdacs.org/gis/calculation/EQ1_WPS/-071/eq_-07150_-01605.xml" version="0">
#
#
# 					<gdacs:title>Affected population and infrastructure</gdacs:title>
#
#
# 					<gdacs:xslt>http://www.gdacs.org/xslt/asgard_summary.xslt&amp;pname=eventtype&amp;pvalue=EQ</gdacs:xslt>
#
#
# 					<gdacs:description>GIS analysis of the area affected by the earthquake</gdacs:description>
#
#
# 					<gdacs:accesslevel>Private</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="gts_message_file" source="JRC" type="txt" url="http://www.gdacs.org/gis/gts_message/EQ/1156643/" version="0">
#
#
# 					<gdacs:title>GTS Message Folder</gdacs:title>
#
#
# 					<gdacs:description>GTS Message generate for episode</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="kml_link" source="JRC" type="kml" url="http://www.gdacs.org/kml.aspx?profile=archive&amp;eventid=1156643&amp;eventtype=EQ" version="0">
#
#
# 					<gdacs:title>KML Event</gdacs:title>
#
#
# 					<gdacs:description>Link to KML data of this event</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="cap_link" source="JRC" type="xml" url="http://www.gdacs.org/cap.aspx?profile=archive&amp;eventid=1156643&amp;eventtype=EQ" version="0">
#
#
# 					<gdacs:title>CAP file</gdacs:title>
#
#
# 					<gdacs:description>Link to CAP data of this event</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="metoffice" source="WMO" type="link" url="http://www.senamhi.gob.pe" version="0">
#
#
# 					<gdacs:title>Servicio Nacional de Meteorología e Hidrología</gdacs:title>
#
#
# 					<gdacs:description>National Hydrometeorological Service of Peru</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="event_rss" source="JRC" type="rss" url="http://www.gdacs.org//datareport/resources/EQ/1156643/rss_1156643.xml" version="0">
#
#
# 					<gdacs:title>Event in rss format</gdacs:title>
#
#
# 					<gdacs:description>The event data in xml format</gdacs:description>
#
#
# 					<gdacs:acknowledgements>NASA Experimental Product</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="event_geojson" source="JRC" type="geojson" url="http://www.gdacs.org//datareport/resources/EQ/1156643/geojson_1156643_1228272.geojson" version="0">
#
#
# 					<gdacs:title>Event in geojson format</gdacs:title>
#
#
# 					<gdacs:acknowledgements>NASA Experimental Product</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Private</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="jsonEvent" source="JRC" type="json" url="http://www.gdacs.org//datareport/resources/EQ/1156643/geojson_1156643_1228272.geojson" version="0">
#
#
# 					<gdacs:title>The Event in GeoJson format</gdacs:title>
#
#
# 					<gdacs:description>The data in json format</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="shakemap_populationmap_static_v01" source="USGS" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156643_1228272__2.png" version="0">
#
#
# 					<gdacs:title>Shakemap Image</gdacs:title>
#
#
# 					<gdacs:description>The Shakemap impact image </gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="shakemap_populationmap_overview_static_v01" source="USGS" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156643_1228272__1.png" version="0">
#
#
# 					<gdacs:title>Population Shakemap Overview </gdacs:title>
#
#
# 					<gdacs:description>The Shakemap impact image zoomed</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="inform_report" source="INFORM" type="link" url=" http://139.191.244.117/GNASystem/isochoice_iframe.aspx?iso3=PER&amp;workflow=360&amp;workflowgroup=INFORM2018" version="0">
#
#
# 					<gdacs:title>Inform Country Report</gdacs:title>
#
#
# 					<gdacs:description>The link to informa data by country specified</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="inform_reference" source="INFORM" type="link" url="http://www.inform-index.org/" version="0">
#
#
# 					<gdacs:title>Inform Website</gdacs:title>
#
#
# 					<gdacs:description>The link to inform website</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="alertbar" source="JRC" type="image" url="http://www.gdacs.org/datareport/resources/EQ/1156643/alertbar_1156643_1228272.jpg" version="0">
#
#
# 					<gdacs:title>Image having the alertbar</gdacs:title>
#
#
# 					<gdacs:acknowledgements>JRC</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Private</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="episode_rss" source="JRC" type="rss" url="http://www.gdacs.org//datareport/resources/EQ/1156643/rss_1156643_1228272.xml" version="0">
#
#
# 					<gdacs:title>Episode in rss format</gdacs:title>
#
#
# 					<gdacs:description>The episode data in xml format</gdacs:description>
#
#
# 					<gdacs:acknowledgements>NASA Experimental Product</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 			</gdacs:resources>
#
#
# 			<gdacs:identifiers>
#
#
# 				<gdacs:identifier id="eqcalculationpath" src="JRC">-071\eq_-07150_-01605.xml</gdacs:identifier>
#
#
# 				<gdacs:identifier id="gdpcapita" src="JRC">2345.6960449</gdacs:identifier>
#
#
# 				<gdacs:identifier id="neicid" src="NEIC">us2000hekx</gdacs:identifier>
#
#
# 			</gdacs:identifiers>
#
#
# 		</item>
#
#
# 		<item>
#
#
# 			<title>Green earthquake alert (Magnitude 4.6M, Depth:107.09km) in Chile 14/09/2018 10:50 UTC, About 19000 people within 100km.</title>
#
#
# 			<description>On 9/14/2018 10:50:38 AM, an earthquake occurred in Chile potentially affecting About 19000 people within 100km. The earthquake had Magnitude 4.6M, Depth:107.09km.</description>
#
#
# 			<enclosure length="1" type="image/png" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228269_1.png"/>
#
#
# 			<gdacs:temporary>false</gdacs:temporary>
#
#
# 			<link>http://www.gdacs.org/report.aspx?eventtype=EQ&amp;eventid=1156641</link>
#
#
# 			<pubDate>Fri, 14 Sep 2018 10:50:38 GMT</pubDate>
#
#
# 			<gdacs:fromdate>Fri, 14 Sep 2018 10:50:38 GMT</gdacs:fromdate>
#
#
# 			<gdacs:todate>Fri, 14 Sep 2018 10:50:38 GMT</gdacs:todate>
#
#
# 			<gdacs:year>2018</gdacs:year>
#
#
# 			<dc:subject>EQ1</dc:subject>
#
#
# 			<guid isPermaLink="false">EQ1156641</guid>
#
#
# 			<geo:Point>
#
#
# 				<geo:lat>-19.2478</geo:lat>
#
#
# 				<geo:long>-69.3235</geo:long>
#
#
# 			</geo:Point>
#
#
# 			<!--gdacs:bbox format = lonmin lonmax latmin latmax-->
#
#
# 			<gdacs:bbox>-73.3235 -65.3235 -23.2478 -15.2478</gdacs:bbox>
#
#
# 			<georss:point>-19.2478 -69.3235</georss:point>
#
#
# 			<gdacs:cap>http://www.gdacs.org/cap.aspx?eventtype=EQ&amp;eventid=1156641</gdacs:cap>
#
#
# 			<gdacs:version>1</gdacs:version>
#
#
# 			<gdacs:eventtype>EQ</gdacs:eventtype>
#
#
# 			<gdacs:alertlevel>Green</gdacs:alertlevel>
#
#
# 			<gdacs:alertscore>0</gdacs:alertscore>
#
#
# 			<gdacs:episodealertlevel>Green</gdacs:episodealertlevel>
#
#
# 			<gdacs:episodealertscore>1</gdacs:episodealertscore>
#
#
# 			<gdacs:eventname/>
#
#
# 			<gdacs:eventid>1156641</gdacs:eventid>
#
#
# 			<gdacs:episodeid>1228269</gdacs:episodeid>
#
#
# 			<gdacs:calculationtype>earthquakeonly</gdacs:calculationtype>
#
#
# 			<gdacs:severity unit="M" value="4.6">Magnitude 4.6M, Depth:107.09km</gdacs:severity>
#
#
# 			<gdacs:population unit="Population in 100km" value="19086">About 19000 people within 100km</gdacs:population>
#
#
# 			<gdacs:vulnerability value="1.3145341380124"/>
#
#
# 			<gdacs:iso3>CHL</gdacs:iso3>
#
#
# 			<gdacs:country>Chile</gdacs:country>
#
#
# 			<gdacs:glide/>
#
#
# 			<gdacs:mapimage/>
#
#
# 			<gdacs:maplink/>
#
#
# 			<gdacs:gtsimage/>
#
#
# 			<gdacs:gtslink/>
#
#
# 			<gdacs:resources>
#
#
# 				<gdacs:resource id="overviewmap" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228269_2.png" version="0">
#
#
# 					<gdacs:title>Population density map</gdacs:title>
#
#
# 					<gdacs:description>The overview image impact with population density layer</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged. Population data from LandScan 2008.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="UNOSATmaps_country" source="" type="html" url="http://www.unitar.org/unosat/maps/CHL" version="0">
#
#
# 					<gdacs:title>UNOSAT maps by country</gdacs:title>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="interactive_event_map" source="JRC" type="map" url="http://dma.gdacs.org/map?application=EARTHQUAKE&amp;eventid=1156641&amp;episodeid=1228269&amp;coordinate=-69.3235,-19.2478" version="0">
#
#
# 					<gdacs:title>Interactive earthquake event map</gdacs:title>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="impact_xml" source="JRC" type="xml" url="http://www.gdacs.org/gis/calculation/EQ1_WPS/-069\eq_-06930_-01925.xml" version="0">
#
#
# 					<gdacs:title>Affected population and infrastructure</gdacs:title>
#
#
# 					<gdacs:xslt>http://www.gdacs.org/xslt/asgard_summary.xslt&amp;pname=eventtype&amp;pvalue=EQ</gdacs:xslt>
#
#
# 					<gdacs:description>GIS analysis of the area affected by the earthquake</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="ocha_sitrep" source="OCHA" type="rss" url="http://www.reliefweb.int/updates?sl=environment-report_listing%252Ctaxonomy_index_tid_source-1503%252Ctaxonomy_index_tid_content_format-10%252Ctaxonomy_index_tid_disaster_type-4628" version="0">
#
#
# 					<gdacs:title>OCHA Situation Reports for Earthquakes</gdacs:title>
#
#
# 					<gdacs:description>List of most recent OCHA situation reports published on ReliefWeb</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="neic_report" source="NEIC" type="html" url="http://earthquake.usgs.gov/earthquakes/eventpage/us2000hekj#summary" version="0">
#
#
# 					<gdacs:title>USGS earthquake report</gdacs:title>
#
#
# 					<gdacs:description>Report of the USGS National Earthquake Information Center</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="geooffice" source="INGV" type="link" url="http://cnt.rm.ingv.it/" version="0">
#
#
# 					<gdacs:title>Istituto Nazionale di Geofisica e Vulcanologia</gdacs:title>
#
#
# 					<gdacs:description>Latest earthquakes recorded by the Italian National Earthquake Centre</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="thumbnailmap_cached" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228269_1.png" version="0">
#
#
# 					<gdacs:title>Overview thumbnail map</gdacs:title>
#
#
# 					<gdacs:description>The Impact thumbanil image</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="populationmap_cached" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228269_4.png" version="0">
#
#
# 					<gdacs:title>Population map close up</gdacs:title>
#
#
# 					<gdacs:description>The impact image</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="desinventar_disasters_profile" source="DesInventar" type="link" url="http://www.desinventar.net/DesInventar/profiletab.jsp?countrycode=ch" version="0">
#
#
# 					<gdacs:title>Country disaster profile (DesInventar)</gdacs:title>
#
#
# 					<gdacs:description>This Country Profile shows a set of typical results known as &quot;Preliminary Analysis&quot; comming from the disaster database. Charts, Maps and tables below will provide you with a basic understanding of the effects of many types of natural disasters occurred in the region.</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="neic_json" source="NEIC" type="json" url="http://earthquake.usgs.gov/earthquakes/eventpage/us2000hekj.json" version="0">
#
#
# 					<gdacs:title>USGS NEIC Json Product Feed</gdacs:title>
#
#
# 					<gdacs:description>Json feed of products available on USGS NEIC website</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="impact_xml_old" source="JRC" type="xml" url="http://www.gdacs.org/gis/calculation/EQ1_WPS/-069/eq_-06930_-01925.xml" version="0">
#
#
# 					<gdacs:title>Affected population and infrastructure</gdacs:title>
#
#
# 					<gdacs:xslt>http://www.gdacs.org/xslt/asgard_summary.xslt&amp;pname=eventtype&amp;pvalue=EQ</gdacs:xslt>
#
#
# 					<gdacs:description>GIS analysis of the area affected by the earthquake</gdacs:description>
#
#
# 					<gdacs:accesslevel>Private</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="gts_message_file" source="JRC" type="txt" url="http://www.gdacs.org/gis/gts_message/EQ/1156641/" version="0">
#
#
# 					<gdacs:title>GTS Message Folder</gdacs:title>
#
#
# 					<gdacs:description>GTS Message generate for episode</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="kml_link" source="JRC" type="kml" url="http://www.gdacs.org/kml.aspx?profile=archive&amp;eventid=1156641&amp;eventtype=EQ" version="0">
#
#
# 					<gdacs:title>KML Event</gdacs:title>
#
#
# 					<gdacs:description>Link to KML data of this event</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="cap_link" source="JRC" type="xml" url="http://www.gdacs.org/cap.aspx?profile=archive&amp;eventid=1156641&amp;eventtype=EQ" version="0">
#
#
# 					<gdacs:title>CAP file</gdacs:title>
#
#
# 					<gdacs:description>Link to CAP data of this event</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="metoffice" source="WMO" type="link" url="http://www.meteochile.cl/PortalDMC-web/index.xhtml" version="0">
#
#
# 					<gdacs:title>Dirección Meteorológica de Chile</gdacs:title>
#
#
# 					<gdacs:description>National Weather Service of Chile</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="event_rss" source="JRC" type="rss" url="http://www.gdacs.org//datareport/resources/EQ/1156641/rss_1156641.xml" version="0">
#
#
# 					<gdacs:title>Event in rss format</gdacs:title>
#
#
# 					<gdacs:description>The event data in xml format</gdacs:description>
#
#
# 					<gdacs:acknowledgements>NASA Experimental Product</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="event_geojson" source="JRC" type="geojson" url="http://www.gdacs.org//datareport/resources/EQ/1156641/geojson_1156641_1228269.geojson" version="0">
#
#
# 					<gdacs:title>Event in geojson format</gdacs:title>
#
#
# 					<gdacs:acknowledgements>NASA Experimental Product</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Private</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="jsonEvent" source="JRC" type="json" url="http://www.gdacs.org//datareport/resources/EQ/1156641/geojson_1156641_1228269.geojson" version="0">
#
#
# 					<gdacs:title>The Event in GeoJson format</gdacs:title>
#
#
# 					<gdacs:description>The data in json format</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="shakemap_populationmap_static_v01" source="USGS" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156641_1228269__2.png" version="0">
#
#
# 					<gdacs:title>Shakemap Image</gdacs:title>
#
#
# 					<gdacs:description>The Shakemap impact image </gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="shakemap_populationmap_overview_static_v01" source="USGS" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156641_1228269__1.png" version="0">
#
#
# 					<gdacs:title>Population Shakemap Overview </gdacs:title>
#
#
# 					<gdacs:description>The Shakemap impact image zoomed</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="inform_report" source="INFORM" type="link" url=" http://139.191.244.117/GNASystem/isochoice_iframe.aspx?iso3=CHL&amp;workflow=360&amp;workflowgroup=INFORM2018" version="0">
#
#
# 					<gdacs:title>Inform Country Report</gdacs:title>
#
#
# 					<gdacs:description>The link to informa data by country specified</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="inform_reference" source="INFORM" type="link" url="http://www.inform-index.org/" version="0">
#
#
# 					<gdacs:title>Inform Website</gdacs:title>
#
#
# 					<gdacs:description>The link to inform website</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="alertbar" source="JRC" type="image" url="http://www.gdacs.org/datareport/resources/EQ/1156641/alertbar_1156641_1228269.jpg" version="0">
#
#
# 					<gdacs:title>Image having the alertbar</gdacs:title>
#
#
# 					<gdacs:acknowledgements>JRC</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Private</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="episode_rss" source="JRC" type="rss" url="http://www.gdacs.org//datareport/resources/EQ/1156641/rss_1156641_1228269.xml" version="0">
#
#
# 					<gdacs:title>Episode in rss format</gdacs:title>
#
#
# 					<gdacs:description>The episode data in xml format</gdacs:description>
#
#
# 					<gdacs:acknowledgements>NASA Experimental Product</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 			</gdacs:resources>
#
#
# 			<gdacs:identifiers>
#
#
# 				<gdacs:identifier id="eqcalculationpath" src="JRC">-069\eq_-06930_-01925.xml</gdacs:identifier>
#
#
# 				<gdacs:identifier id="gdpcapita" src="JRC">5121.3950195</gdacs:identifier>
#
#
# 				<gdacs:identifier id="neicid" src="NEIC">us2000hekj</gdacs:identifier>
#
#
# 			</gdacs:identifiers>
#
#
# 		</item>
#
#
# 		<item>
#
#
# 			<title>Green alert for tropical cyclone FLORENCE-18. Population affected by Category 1 (120 km/h) wind speeds or higher is 0.</title>
#
#
# 			<description>From 31/08/2018 to 14/09/2018, a Hurricane/Typhoon &gt; 74 mph (maximum wind speed of 222 km/h) FLORENCE-18 was active in Atlantic. The cyclone affects these countries: United States (vulnerability Low). Estimated population affected by category 1 (120 km/h) wind speeds or higher is 0.</description>
#
#
# 			<enclosure length="1" type="image/png" url="http://dma.gdacs.org/saved/gdacs/tc/1000495/1000495_60_tn.png"/>
#
#
# 			<gdacs:temporary>false</gdacs:temporary>
#
#
# 			<link>http://www.gdacs.org/report.aspx?eventtype=TC&amp;eventid=1000495</link>
#
#
# 			<pubDate>Fri, 14 Sep 2018 09:00:00 GMT</pubDate>
#
#
# 			<gdacs:fromdate>Fri, 31 Aug 2018 21:00:00 GMT</gdacs:fromdate>
#
#
# 			<gdacs:todate>Fri, 14 Sep 2018 09:00:00 GMT</gdacs:todate>
#
#
# 			<gdacs:year>2018</gdacs:year>
#
#
# 			<dc:subject>TC1</dc:subject>
#
#
# 			<guid isPermaLink="false">TC1000495</guid>
#
#
# 			<geo:Point>
#
#
# 				<geo:lat>34.2</geo:lat>
#
#
# 				<geo:long>-77.4</geo:long>
#
#
# 			</geo:Point>
#
#
# 			<!--gdacs:bbox format = lonmin lonmax latmin latmax-->
#
#
# 			<gdacs:bbox>-74.7585404718431 -48.7585404718431 14.1430380900754 40.1430380900754</gdacs:bbox>
#
#
# 			<georss:point>34.2 -77.4</georss:point>
#
#
# 			<gdacs:cap>http://www.gdacs.org/cap.aspx?eventtype=TC&amp;eventid=1000495</gdacs:cap>
#
#
# 			<gdacs:version>60</gdacs:version>
#
#
# 			<gdacs:eventtype>TC</gdacs:eventtype>
#
#
# 			<gdacs:alertlevel>Green</gdacs:alertlevel>
#
#
# 			<gdacs:alertscore>1</gdacs:alertscore>
#
#
# 			<gdacs:episodealertlevel>Green</gdacs:episodealertlevel>
#
#
# 			<gdacs:episodealertscore>1</gdacs:episodealertscore>
#
#
# 			<gdacs:eventname>FLORENCE-18</gdacs:eventname>
#
#
# 			<gdacs:eventid>1000495</gdacs:eventid>
#
#
# 			<gdacs:episodeid>60</gdacs:episodeid>
#
#
# 			<gdacs:calculationtype>tropicalcyclonewithstormsurge</gdacs:calculationtype>
#
#
# 			<gdacs:severity unit="km/h" value="148.1472">Hurricane/Typhoon &gt; 74 mph (maximum wind speed of 148 km/h)</gdacs:severity>
#
#
# 			<gdacs:population unit="Pop74" value="1827500">Population affected by Category 1 (120 km/h) wind speeds or higher is 1.827 million</gdacs:population>
#
#
# 			<gdacs:vulnerability value="1">Low</gdacs:vulnerability>
#
#
# 			<gdacs:iso3>USA</gdacs:iso3>
#
#
# 			<gdacs:country>United States</gdacs:country>
#
#
# 			<gdacs:glide/>
#
#
# 			<gdacs:mapimage>http://www.gdacs.org/contentdata/maps/daily/TC/1000495/ECDM_20180913_TC_FLORENCE.png</gdacs:mapimage>
#
#
# 			<gdacs:maplink>http://www.gdacs.org/contentdata/maps/daily/TC/1000495/ECDM_20180913_TC_FLORENCE.pdf</gdacs:maplink>
#
#
# 			<gdacs:gtsimage/>
#
#
# 			<gdacs:gtslink/>
#
#
# 			<gdacs:resources>
#
#
# 				<gdacs:resource id="UNOSATmaps_country" source="" type="html" url="http://www.unitar.org/unosat/maps/USA" version="0">
#
#
# 					<gdacs:title>UNOSAT maps by country</gdacs:title>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="interactive_event_map" source="JRC" type="map" url="http://dma.gdacs.org/map?application=CYCLONES" version="0">
#
#
# 					<gdacs:title>Interactive event map</gdacs:title>
#
#
# 					<gdacs:description>Link to interactive cyclone map</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="interactive_map" source="JRC" type="map" url="http://dma.gdacs.org/map?application=CYCLONES" version="0">
#
#
# 					<gdacs:title>Interactive map</gdacs:title>
#
#
# 					<gdacs:description>Link to interactive cyclone bulletin map</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="link_bom" source="BOM" type="link" url="http://www.bom.gov.au/cyclone/index.shtml" version="0">
#
#
# 					<gdacs:title>Bureau of Meteorology of Australia</gdacs:title>
#
#
# 					<gdacs:accesslevel>Link</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="link_ptwc" source="JTWC" type="link" url="http://www.usno.navy.mil/JTWC/" version="0">
#
#
# 					<gdacs:title>Joint Typhoon Warning Centre</gdacs:title>
#
#
# 					<gdacs:accesslevel>Link</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="link_unisys_basin" source="" type="link" url="http://weather.unisys.com/hurricane/atlantic/2018/index.php" version="0">
#
#
# 					<gdacs:title>Unisys </gdacs:title>
#
#
# 					<gdacs:description>Unisys provides data and charts for weather experts</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="nasa_earth_observatory" source="NASA" type="rss" url="http://earthobservatory.nasa.gov/Feeds/rss/nh.rss" version="0">
#
#
# 					<gdacs:title>Imagery of the NASA Earth Observatory</gdacs:title>
#
#
# 					<gdacs:xslt>xslt/rss_default.xslt&amp;pname=contains&amp;pvalue={eventname|~0,-}</gdacs:xslt>
#
#
# 					<gdacs:description>NASA publishes relevant images related to natural disasters from the many operational sensors</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="noaa_nesdis_event" source="NOAA" type="link" url="http://www.ssd.noaa.gov/PS/TROP/storms/FLORENCE.html" version="0">
#
#
# 					<gdacs:title>Tropical cyclones potential rainfall (NOAA/NESDIS)</gdacs:title>
#
#
# 					<gdacs:description>Website dedicated to the rainfall estimation associated with tropical cyclones</gdacs:description>
#
#
# 					<gdacs:accesslevel>Link</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="ocha_sitrep" source="OCHA" type="rss" url="http://www.reliefweb.int/updates/rss.xml?sl=environment-report_listing%252Ctaxonomy_index_tid_source-1503%252Ctaxonomy_index_tid_content_format-10%252Ctaxonomy_index_tid_disaster_type-4618" version="0">
#
#
# 					<gdacs:title>OCHA Situation Reports for Tropical Cyclones</gdacs:title>
#
#
# 					<gdacs:description>List of most recent OCHA situation reports published on ReliefWeb</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="overviewmap" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/tc/1000495/clouds_1000495_60.png" version="0">
#
#
# 					<gdacs:title>Overview map</gdacs:title>
#
#
# 					<gdacs:description>The image of Cyclone</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="rainmap_cached" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/tc/1000495/rain_1000495_60.png" version="0">
#
#
# 					<gdacs:title>Extreme rainfall</gdacs:title>
#
#
# 					<gdacs:description>The map shows the accumulated precipitation along the cyclone's track. Yellow area is &gt; 100mm; Red area is &gt; 300mm; Blue area is &gt; 500mm. The accumulated rainfall is calculated based on the Tropical Rainfall Potential of NOAA/NESDIS. The eTRaP is a simple ensemble whose members are the 6-hourly totals from the single-orbit TRaPs, which are rainfall estimates from passive microwave remote sensing.</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="rainmap_original" source="NOAA" type="image" url="http://www.ssd.noaa.gov/PS/TROP/DATA/ETRAP/2018/Atlantic/FLORENCE/2018FLORENCE.pmqpf.09140900.00.GIF" version="0">
#
#
# 					<gdacs:title>Extreme rainfall (original)</gdacs:title>
#
#
# 					<gdacs:description>The original map shows the accumulated precipitation along the cyclone's track. Yellow area is &gt; 100mm; Red area is &gt; 300mm; Blue area is &gt; 500mm. The accumulated rainfall is calculated based on the Tropical Rainfall Potential of NOAA/NESDIS. The eTRaP is a simple ensemble whose members are the 6-hourly totals from the single-orbit TRaPs, which are rainfall estimates from passive microwave remote sensing.</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="thumbnailmap_cached" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/tc/1000495/1000495_60_tn.png" version="0">
#
#
# 					<gdacs:title>Overview thumbnail map</gdacs:title>
#
#
# 					<gdacs:description>Small overview map</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="unisys_track" source="Unisys" type="image" url="http://weather.unisys.com/hurricane/s_indian/2018/FLORENCE/track.gif" version="0">
#
#
# 					<gdacs:title>Track (Unisys)</gdacs:title>
#
#
# 					<gdacs:description>The external link to Unisys Track</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="kml_link" source="JRC" type="kml" url="http://www.gdacs.org/kml.aspx?profile=archive&amp;eventid=1000495&amp;eventtype=TC" version="0">
#
#
# 					<gdacs:title>KML Event</gdacs:title>
#
#
# 					<gdacs:description>Link to KML data of this event</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="cap_link" source="JRC" type="xml" url="http://www.gdacs.org/cap.aspx?profile=archive&amp;eventid=1000495&amp;eventtype=TC" version="0">
#
#
# 					<gdacs:title>CAP file</gdacs:title>
#
#
# 					<gdacs:description>Link to CAP data of this event</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="metoffice" source="WMO" type="link" url="http://www.weather.gov" version="0">
#
#
# 					<gdacs:title>National Oceanic and Atmospheric Administration</gdacs:title>
#
#
# 					<gdacs:description>National Weather Service of U.S.A.</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="storm_surge_animation" source="JRC" type="image" url="http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/final/outres1.gif" version="0">
#
#
# 					<gdacs:title>Storm surge animation</gdacs:title>
#
#
# 					<gdacs:description>The Storm surge animation gif for all cylone's bulletins</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="storm_surge_maxheight" source="JRC" type="image" url="http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/final/P1_MAXHEIGHT_END.jpg" version="0">
#
#
# 					<gdacs:title>Storm surge maximum height</gdacs:title>
#
#
# 					<gdacs:description>The Strom surge maxheight </gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="storm_surge_data" source="JRC" type="data" url="http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/final/" version="0">
#
#
# 					<gdacs:title>Storm surge event results</gdacs:title>
#
#
# 					<gdacs:description>The folder containing the Storm surge data</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="storm_surge_locations_affected_kmz" source="JRC" type="kmz" url="http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/final/locations.kmz" version="0">
#
#
# 					<gdacs:title>Storm surge overview for Google Earth</gdacs:title>
#
#
# 					<gdacs:description>The stormsurge in kmz format </gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="episode_data" source="JRC" type="data" url="http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/60/" version="0">
#
#
# 					<gdacs:title>GIS data and impact analyses (latest episode)</gdacs:title>
#
#
# 					<gdacs:description>The folder containing the Cyclone episode GIS data</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="impact_data" source="JRC" type="data" url="http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/" version="0">
#
#
# 					<gdacs:title>GIS data and impact analyses</gdacs:title>
#
#
# ...
#
#
# 			<gdacs:identifiers>
#
#
# 				<gdacs:identifier id="emscid" src="EMSC">712686</gdacs:identifier>
#
#
# 				<gdacs:identifier id="eqcalculationpath" src="JRC">046\eq_04615_03460.xml</gdacs:identifier>
#
#
# 				<gdacs:identifier id="gdpcapita" src="JRC">1586.6134033</gdacs:identifier>
#
#
# 			</gdacs:identifiers>
#
#
# 		</item>
#
#
# 		<item>
#
#
# 			<title>Green earthquake alert (Magnitude 5M, Depth:137.44km) in Indonesia 13/09/2018 16:49 UTC, About 26000 people within 100km.</title>
#
#
# 			<description>On 9/13/2018 4:49:16 PM, an earthquake occurred in Indonesia potentially affecting About 26000 people within 100km. The earthquake had Magnitude 5M, Depth:137.44km.</description>
#
#
# 			<enclosure length="1" type="image/png" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228174_1.png"/>
#
#
# 			<gdacs:temporary>false</gdacs:temporary>
#
#
# 			<link>http://www.gdacs.org/report.aspx?eventtype=EQ&amp;eventid=1156579</link>
#
#
# 			<pubDate>Thu, 13 Sep 2018 16:49:16 GMT</pubDate>
#
#
# 			<gdacs:fromdate>Thu, 13 Sep 2018 16:49:16 GMT</gdacs:fromdate>
#
#
# 			<gdacs:todate>Thu, 13 Sep 2018 16:49:16 GMT</gdacs:todate>
#
#
# 			<gdacs:year>2018</gdacs:year>
#
#
# 			<dc:subject>EQ1</dc:subject>
#
#
# 			<guid isPermaLink="false">EQ1156579</guid>
#
#
# 			<geo:Point>
#
#
# 				<geo:lat>3.1954</geo:lat>
#
#
# 				<geo:long>128.1078</geo:long>
#
#
# 			</geo:Point>
#
#
# 			<!--gdacs:bbox format = lonmin lonmax latmin latmax-->
#
#
# 			<gdacs:bbox>124.1078 132.1078 -0.8046 7.1954</gdacs:bbox>
#
#
# 			<georss:point>3.1954 128.1078</georss:point>
#
#
# 			<gdacs:cap>http://www.gdacs.org/cap.aspx?eventtype=EQ&amp;eventid=1156579</gdacs:cap>
#
#
# 			<gdacs:version>1</gdacs:version>
#
#
# 			<gdacs:eventtype>EQ</gdacs:eventtype>
#
#
# 			<gdacs:alertlevel>Green</gdacs:alertlevel>
#
#
# 			<gdacs:alertscore>0</gdacs:alertscore>
#
#
# 			<gdacs:episodealertlevel>Green</gdacs:episodealertlevel>
#
#
# 			<gdacs:episodealertscore>1</gdacs:episodealertscore>
#
#
# 			<gdacs:eventname/>
#
#
# 			<gdacs:eventid>1156579</gdacs:eventid>
#
#
# 			<gdacs:episodeid>1228174</gdacs:episodeid>
#
#
# 			<gdacs:calculationtype>earthquakeonly</gdacs:calculationtype>
#
#
# 			<gdacs:severity unit="M" value="5">Magnitude 5M, Depth:137.44km</gdacs:severity>
#
#
# 			<gdacs:population unit="Population in 100km" value="26563">About 26000 people within 100km</gdacs:population>
#
#
# 			<gdacs:vulnerability value="1.62113293717696"/>
#
#
# 			<gdacs:iso3>IDN</gdacs:iso3>
#
#
# 			<gdacs:country>Indonesia</gdacs:country>
#
#
# 			<gdacs:glide/>
#
#
# 			<gdacs:mapimage/>
#
#
# 			<gdacs:maplink/>
#
#
# 			<gdacs:gtsimage/>
#
#
# 			<gdacs:gtslink/>
#
#
# 			<gdacs:resources>
#
#
# 				<gdacs:resource id="overviewmap" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228174_2.png" version="0">
#
#
# 					<gdacs:title>Population density map</gdacs:title>
#
#
# 					<gdacs:description>The overview image impact with population density layer</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged. Population data from LandScan 2008.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="UNOSATmaps_country" source="" type="html" url="http://www.unitar.org/unosat/maps/IDN" version="0">
#
#
# 					<gdacs:title>UNOSAT maps by country</gdacs:title>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="interactive_event_map" source="JRC" type="map" url="http://dma.gdacs.org/map?application=EARTHQUAKE&amp;eventid=1156579&amp;episodeid=1228174&amp;coordinate=128.1078,3.1954" version="0">
#
#
# 					<gdacs:title>Interactive earthquake event map</gdacs:title>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="impact_xml" source="JRC" type="xml" url="http://www.gdacs.org/gis/calculation/EQ1_WPS/128\eq_12810_00320.xml" version="0">
#
#
# 					<gdacs:title>Affected population and infrastructure</gdacs:title>
#
#
# 					<gdacs:xslt>http://www.gdacs.org/xslt/asgard_summary.xslt&amp;pname=eventtype&amp;pvalue=EQ</gdacs:xslt>
#
#
# 					<gdacs:description>GIS analysis of the area affected by the earthquake</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="ocha_sitrep" source="OCHA" type="rss" url="http://www.reliefweb.int/updates?sl=environment-report_listing%252Ctaxonomy_index_tid_source-1503%252Ctaxonomy_index_tid_content_format-10%252Ctaxonomy_index_tid_disaster_type-4628" version="0">
#
#
# 					<gdacs:title>OCHA Situation Reports for Earthquakes</gdacs:title>
#
#
# 					<gdacs:description>List of most recent OCHA situation reports published on ReliefWeb</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="neic_report" source="NEIC" type="html" url="http://earthquake.usgs.gov/earthquakes/eventpage/us2000he1s#summary" version="0">
#
#
# 					<gdacs:title>USGS earthquake report</gdacs:title>
#
#
# 					<gdacs:description>Report of the USGS National Earthquake Information Center</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="geooffice" source="INGV" type="link" url="http://cnt.rm.ingv.it/" version="0">
#
#
# 					<gdacs:title>Istituto Nazionale di Geofisica e Vulcanologia</gdacs:title>
#
#
# 					<gdacs:description>Latest earthquakes recorded by the Italian National Earthquake Centre</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="thumbnailmap_cached" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228174_1.png" version="0">
#
#
# 					<gdacs:title>Overview thumbnail map</gdacs:title>
#
#
# 					<gdacs:description>The Impact thumbanil image</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="populationmap_cached" source="JRC" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/eq1228174_4.png" version="0">
#
#
# 					<gdacs:title>Population map close up</gdacs:title>
#
#
# 					<gdacs:description>The impact image</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="desinventar_disasters_profile" source="DesInventar" type="link" url="http://www.desinventar.net/DesInventar/profiletab.jsp?countrycode=id3" version="0">
#
#
# 					<gdacs:title>Country disaster profile (DesInventar)</gdacs:title>
#
#
# 					<gdacs:description>This Country Profile shows a set of typical results known as &quot;Preliminary Analysis&quot; comming from the disaster database. Charts, Maps and tables below will provide you with a basic understanding of the effects of many types of natural disasters occurred in the region.</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="neic_json" source="NEIC" type="json" url="http://earthquake.usgs.gov/earthquakes/eventpage/us2000he1s.json" version="0">
#
#
# 					<gdacs:title>USGS NEIC Json Product Feed</gdacs:title>
#
#
# 					<gdacs:description>Json feed of products available on USGS NEIC website</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="impact_xml_old" source="JRC" type="xml" url="http://www.gdacs.org/gis/calculation/EQ1_WPS/128/eq_12810_00320.xml" version="0">
#
#
# 					<gdacs:title>Affected population and infrastructure</gdacs:title>
#
#
# 					<gdacs:xslt>http://www.gdacs.org/xslt/asgard_summary.xslt&amp;pname=eventtype&amp;pvalue=EQ</gdacs:xslt>
#
#
# 					<gdacs:description>GIS analysis of the area affected by the earthquake</gdacs:description>
#
#
# 					<gdacs:accesslevel>Private</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="gts_message_file" source="JRC" type="txt" url="http://www.gdacs.org/gis/gts_message/EQ/1156579/" version="0">
#
#
# 					<gdacs:title>GTS Message Folder</gdacs:title>
#
#
# 					<gdacs:description>GTS Message generate for episode</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="kml_link" source="JRC" type="kml" url="http://www.gdacs.org/kml.aspx?profile=archive&amp;eventid=1156579&amp;eventtype=EQ" version="0">
#
#
# 					<gdacs:title>KML Event</gdacs:title>
#
#
# 					<gdacs:description>Link to KML data of this event</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="cap_link" source="JRC" type="xml" url="http://www.gdacs.org/cap.aspx?profile=archive&amp;eventid=1156579&amp;eventtype=EQ" version="0">
#
#
# 					<gdacs:title>CAP file</gdacs:title>
#
#
# 					<gdacs:description>Link to CAP data of this event</gdacs:description>
#
#
# 					<gdacs:acknowledgements>Copyright European Union. Syndication allowed, provided the source is acknowledged.</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="metoffice" source="WMO" type="link" url="http://www.bmkg.go.id" version="0">
#
#
# 					<gdacs:title>Meteorological and Geophysical Agency</gdacs:title>
#
#
# 					<gdacs:description>National Weather Service of Indonesia</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="event_rss" source="JRC" type="rss" url="http://www.gdacs.org//datareport/resources/EQ/1156579/rss_1156579.xml" version="0">
#
#
# 					<gdacs:title>Event in rss format</gdacs:title>
#
#
# 					<gdacs:description>The event data in xml format</gdacs:description>
#
#
# 					<gdacs:acknowledgements>NASA Experimental Product</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="event_geojson" source="JRC" type="geojson" url="http://www.gdacs.org//datareport/resources/EQ/1156579/geojson_1156579_1228174.geojson" version="0">
#
#
# 					<gdacs:title>Event in geojson format</gdacs:title>
#
#
# 					<gdacs:acknowledgements>NASA Experimental Product</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Private</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="jsonEvent" source="JRC" type="json" url="http://www.gdacs.org//datareport/resources/EQ/1156579/geojson_1156579_1228174.geojson" version="0">
#
#
# 					<gdacs:title>The Event in GeoJson format</gdacs:title>
#
#
# 					<gdacs:description>The data in json format</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="shakemap_populationmap_static_v01" source="USGS" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156579_1228174__2.png" version="0">
#
#
# 					<gdacs:title>Shakemap Image</gdacs:title>
#
#
# 					<gdacs:description>The Shakemap impact image </gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="shakemap_populationmap_overview_static_v01" source="USGS" type="image" url="http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156579_1228174__1.png" version="0">
#
#
# 					<gdacs:title>Population Shakemap Overview </gdacs:title>
#
#
# 					<gdacs:description>The Shakemap impact image zoomed</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="inform_report" source="INFORM" type="link" url=" http://139.191.244.117/GNASystem/isochoice_iframe.aspx?iso3=IDN&amp;workflow=360&amp;workflowgroup=INFORM2018" version="0">
#
#
# 					<gdacs:title>Inform Country Report</gdacs:title>
#
#
# 					<gdacs:description>The link to informa data by country specified</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="inform_reference" source="INFORM" type="link" url="http://www.inform-index.org/" version="0">
#
#
# 					<gdacs:title>Inform Website</gdacs:title>
#
#
# 					<gdacs:description>The link to inform website</gdacs:description>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="alertbar" source="JRC" type="image" url="http://www.gdacs.org/datareport/resources/EQ/1156579/alertbar_1156579_1228174.jpg" version="0">
#
#
# 					<gdacs:title>Image having the alertbar</gdacs:title>
#
#
# 					<gdacs:acknowledgements>JRC</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Private</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 				<gdacs:resource id="episode_rss" source="JRC" type="rss" url="http://www.gdacs.org//datareport/resources/EQ/1156579/rss_1156579_1228174.xml" version="0">
#
#
# 					<gdacs:title>Episode in rss format</gdacs:title>
#
#
# 					<gdacs:description>The episode data in xml format</gdacs:description>
#
#
# 					<gdacs:acknowledgements>NASA Experimental Product</gdacs:acknowledgements>
#
#
# 					<gdacs:accesslevel>Public</gdacs:accesslevel>
#
#
# 				</gdacs:resource>
#
#
# 			</gdacs:resources>
#
#
# 			<gdacs:identifiers>
#
#
# 				<gdacs:identifier id="eqcalculationpath" src="JRC">128\eq_12810_00320.xml</gdacs:identifier>
#
#
# 				<gdacs:identifier id="gdpcapita" src="JRC">961.83758545</gdacs:identifier>
#
#
# 				<gdacs:identifier id="neicid" src="NEIC">us2000he1s</gdacs:identifier>
#
#
# 			</gdacs:identifiers>
#
#
# 		</item>
#
#
# 	</channel>
#
#
# </rss>
# <!--End 9/14/2018 4:16:51 PM-->

# %%
tree = ET.parse(feed)
root = tree.getroot()
print root
# Out:
# <Element 'rss' at 0x1088bafd0>

# %%
for element in root[0].iter():
    print element.tag, element.attrib
# Out:
# channel {}
# title {}
# link {}
# description {}
# managingEditor {}
# webMaster {}
# pubDate {}
# {http://www.w3.org/2005/Atom}link {'href': 'http://www.gdacs.org/xml/rss_24h.xml', 'type': 'application/rss+xml', 'rel': 'self'}
# item {}
# title {}
# description {}
# enclosure {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228272_1.png', 'length': '1', 'type': 'image/png'}
# {http://www.gdacs.org}temporary {}
# link {}
# pubDate {}
# {http://www.gdacs.org}fromdate {}
# {http://www.gdacs.org}todate {}
# {http://www.gdacs.org}year {}
# {http://purl.org/dc/elements/1.1/}subject {}
# guid {'isPermaLink': 'false'}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}Point {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}lat {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}long {}
# {http://www.gdacs.org}bbox {}
# {http://www.georss.org/georss}point {}
# {http://www.gdacs.org}cap {}
# {http://www.gdacs.org}version {}
# {http://www.gdacs.org}eventtype {}
# {http://www.gdacs.org}alertlevel {}
# {http://www.gdacs.org}alertscore {}
# {http://www.gdacs.org}episodealertlevel {}
# {http://www.gdacs.org}episodealertscore {}
# {http://www.gdacs.org}eventname {}
# {http://www.gdacs.org}eventid {}
# {http://www.gdacs.org}episodeid {}
# {http://www.gdacs.org}calculationtype {}
# {http://www.gdacs.org}severity {'unit': 'M', 'value': '5.4'}
# {http://www.gdacs.org}population {'unit': 'Population in 100km', 'value': '1058015'}
# {http://www.gdacs.org}vulnerability {'value': '1.78228028098837'}
# {http://www.gdacs.org}iso3 {}
# {http://www.gdacs.org}country {}
# {http://www.gdacs.org}glide {}
# {http://www.gdacs.org}mapimage {}
# {http://www.gdacs.org}maplink {}
# {http://www.gdacs.org}gtsimage {}
# {http://www.gdacs.org}gtslink {}
# {http://www.gdacs.org}resources {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228272_2.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'overviewmap'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.unitar.org/unosat/maps/PER', 'source': '', 'version': '0', 'type': 'html', 'id': 'UNOSATmaps_country'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/map?application=EARTHQUAKE&eventid=1156643&episodeid=1228272&coordinate=-71.4991,-16.0473', 'source': 'JRC', 'version': '0', 'type': 'map', 'id': 'interactive_event_map'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/calculation/EQ1_WPS/-071\\eq_-07150_-01605.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'impact_xml'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.reliefweb.int/updates?sl=environment-report_listing%252Ctaxonomy_index_tid_source-1503%252Ctaxonomy_index_tid_content_format-10%252Ctaxonomy_index_tid_disaster_type-4628', 'source': 'OCHA', 'version': '0', 'type': 'rss', 'id': 'ocha_sitrep'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://earthquake.usgs.gov/earthquakes/eventpage/us2000hekx#summary', 'source': 'NEIC', 'version': '0', 'type': 'html', 'id': 'neic_report'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://cnt.rm.ingv.it/', 'source': 'INGV', 'version': '0', 'type': 'link', 'id': 'geooffice'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228272_1.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'thumbnailmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228272_4.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'populationmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http:/www.desinventar.net/DesInventar/profiletab.jsp?countrycode=pe', 'source': 'DesInventar', 'version': '0', 'type': 'link', 'id': 'desinventar_disasters_profile'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://earthquake.usgs.gov/earthquakes/eventpage/us2000hekx.json', 'source': 'NEIC', 'version': '0', 'type': 'json', 'id': 'neic_json'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/calculation/EQ1_WPS/-071/eq_-07150_-01605.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'impact_xml_old'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/gts_message/EQ/1156643/', 'source': 'JRC', 'version': '0', 'type': 'txt', 'id': 'gts_message_file'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/kml.aspx?profile=archive&eventid=1156643&eventtype=EQ', 'source': 'JRC', 'version': '0', 'type': 'kml', 'id': 'kml_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/cap.aspx?profile=archive&eventid=1156643&eventtype=EQ', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'cap_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.senamhi.gob.pe', 'source': 'WMO', 'version': '0', 'type': 'link', 'id': 'metoffice'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156643/rss_1156643.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'event_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156643/geojson_1156643_1228272.geojson', 'source': 'JRC', 'version': '0', 'type': 'geojson', 'id': 'event_geojson'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156643/geojson_1156643_1228272.geojson', 'source': 'JRC', 'version': '0', 'type': 'json', 'id': 'jsonEvent'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156643_1228272__2.png', 'source': 'USGS', 'version': '0', 'type': 'image', 'id': 'shakemap_populationmap_static_v01'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156643_1228272__1.png', 'source': 'USGS', 'version': '0', 'type': 'image', 'id': 'shakemap_populationmap_overview_static_v01'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': ' http://139.191.244.117/GNASystem/isochoice_iframe.aspx?iso3=PER&workflow=360&workflowgroup=INFORM2018', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_report'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.inform-index.org/', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_reference'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/datareport/resources/EQ/1156643/alertbar_1156643_1228272.jpg', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'alertbar'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156643/rss_1156643_1228272.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'episode_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}identifiers {}
# {http://www.gdacs.org}identifier {'src': 'JRC', 'id': 'eqcalculationpath'}
# {http://www.gdacs.org}identifier {'src': 'JRC', 'id': 'gdpcapita'}
# {http://www.gdacs.org}identifier {'src': 'NEIC', 'id': 'neicid'}
# item {}
# title {}
# description {}
# enclosure {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228269_1.png', 'length': '1', 'type': 'image/png'}
# {http://www.gdacs.org}temporary {}
# link {}
# pubDate {}
# {http://www.gdacs.org}fromdate {}
# {http://www.gdacs.org}todate {}
# {http://www.gdacs.org}year {}
# {http://purl.org/dc/elements/1.1/}subject {}
# guid {'isPermaLink': 'false'}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}Point {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}lat {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}long {}
# {http://www.gdacs.org}bbox {}
# {http://www.georss.org/georss}point {}
# {http://www.gdacs.org}cap {}
# {http://www.gdacs.org}version {}
# {http://www.gdacs.org}eventtype {}
# {http://www.gdacs.org}alertlevel {}
# {http://www.gdacs.org}alertscore {}
# {http://www.gdacs.org}episodealertlevel {}
# {http://www.gdacs.org}episodealertscore {}
# {http://www.gdacs.org}eventname {}
# {http://www.gdacs.org}eventid {}
# {http://www.gdacs.org}episodeid {}
# {http://www.gdacs.org}calculationtype {}
# {http://www.gdacs.org}severity {'unit': 'M', 'value': '4.6'}
# {http://www.gdacs.org}population {'unit': 'Population in 100km', 'value': '19086'}
# {http://www.gdacs.org}vulnerability {'value': '1.3145341380124'}
# {http://www.gdacs.org}iso3 {}
# {http://www.gdacs.org}country {}
# {http://www.gdacs.org}glide {}
# {http://www.gdacs.org}mapimage {}
# {http://www.gdacs.org}maplink {}
# {http://www.gdacs.org}gtsimage {}
# {http://www.gdacs.org}gtslink {}
# {http://www.gdacs.org}resources {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228269_2.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'overviewmap'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.unitar.org/unosat/maps/CHL', 'source': '', 'version': '0', 'type': 'html', 'id': 'UNOSATmaps_country'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/map?application=EARTHQUAKE&eventid=1156641&episodeid=1228269&coordinate=-69.3235,-19.2478', 'source': 'JRC', 'version': '0', 'type': 'map', 'id': 'interactive_event_map'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/calculation/EQ1_WPS/-069\\eq_-06930_-01925.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'impact_xml'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.reliefweb.int/updates?sl=environment-report_listing%252Ctaxonomy_index_tid_source-1503%252Ctaxonomy_index_tid_content_format-10%252Ctaxonomy_index_tid_disaster_type-4628', 'source': 'OCHA', 'version': '0', 'type': 'rss', 'id': 'ocha_sitrep'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://earthquake.usgs.gov/earthquakes/eventpage/us2000hekj#summary', 'source': 'NEIC', 'version': '0', 'type': 'html', 'id': 'neic_report'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://cnt.rm.ingv.it/', 'source': 'INGV', 'version': '0', 'type': 'link', 'id': 'geooffice'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228269_1.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'thumbnailmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228269_4.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'populationmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.desinventar.net/DesInventar/profiletab.jsp?countrycode=ch', 'source': 'DesInventar', 'version': '0', 'type': 'link', 'id': 'desinventar_disasters_profile'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://earthquake.usgs.gov/earthquakes/eventpage/us2000hekj.json', 'source': 'NEIC', 'version': '0', 'type': 'json', 'id': 'neic_json'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/calculation/EQ1_WPS/-069/eq_-06930_-01925.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'impact_xml_old'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/gts_message/EQ/1156641/', 'source': 'JRC', 'version': '0', 'type': 'txt', 'id': 'gts_message_file'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/kml.aspx?profile=archive&eventid=1156641&eventtype=EQ', 'source': 'JRC', 'version': '0', 'type': 'kml', 'id': 'kml_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/cap.aspx?profile=archive&eventid=1156641&eventtype=EQ', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'cap_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.meteochile.cl/PortalDMC-web/index.xhtml', 'source': 'WMO', 'version': '0', 'type': 'link', 'id': 'metoffice'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156641/rss_1156641.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'event_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156641/geojson_1156641_1228269.geojson', 'source': 'JRC', 'version': '0', 'type': 'geojson', 'id': 'event_geojson'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156641/geojson_1156641_1228269.geojson', 'source': 'JRC', 'version': '0', 'type': 'json', 'id': 'jsonEvent'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156641_1228269__2.png', 'source': 'USGS', 'version': '0', 'type': 'image', 'id': 'shakemap_populationmap_static_v01'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156641_1228269__1.png', 'source': 'USGS', 'version': '0', 'type': 'image', 'id': 'shakemap_populationmap_overview_static_v01'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': ' http://139.191.244.117/GNASystem/isochoice_iframe.aspx?iso3=CHL&workflow=360&workflowgroup=INFORM2018', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_report'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.inform-index.org/', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_reference'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/datareport/resources/EQ/1156641/alertbar_1156641_1228269.jpg', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'alertbar'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156641/rss_1156641_1228269.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'episode_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}identifiers {}
# {http://www.gdacs.org}identifier {'src': 'JRC', 'id': 'eqcalculationpath'}
# {http://www.gdacs.org}identifier {'src': 'JRC', 'id': 'gdpcapita'}
# {http://www.gdacs.org}identifier {'src': 'NEIC', 'id': 'neicid'}
# item {}
# title {}
# description {}
# enclosure {'url': 'http://dma.gdacs.org/saved/gdacs/tc/1000495/1000495_60_tn.png', 'length': '1', 'type': 'image/png'}
# {http://www.gdacs.org}temporary {}
# link {}
# pubDate {}
# {http://www.gdacs.org}fromdate {}
# {http://www.gdacs.org}todate {}
# {http://www.gdacs.org}year {}
# {http://purl.org/dc/elements/1.1/}subject {}
# guid {'isPermaLink': 'false'}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}Point {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}lat {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}long {}
# {http://www.gdacs.org}bbox {}
# {http://www.georss.org/georss}point {}
# {http://www.gdacs.org}cap {}
# {http://www.gdacs.org}version {}
# {http://www.gdacs.org}eventtype {}
# {http://www.gdacs.org}alertlevel {}
# {http://www.gdacs.org}alertscore {}
# {http://www.gdacs.org}episodealertlevel {}
# {http://www.gdacs.org}episodealertscore {}
# {http://www.gdacs.org}eventname {}
# {http://www.gdacs.org}eventid {}
# {http://www.gdacs.org}episodeid {}
# {http://www.gdacs.org}calculationtype {}
# {http://www.gdacs.org}severity {'unit': 'km/h', 'value': '148.1472'}
# {http://www.gdacs.org}population {'unit': 'Pop74', 'value': '1827500'}
# {http://www.gdacs.org}vulnerability {'value': '1'}
# {http://www.gdacs.org}iso3 {}
# {http://www.gdacs.org}country {}
# {http://www.gdacs.org}glide {}
# {http://www.gdacs.org}mapimage {}
# {http://www.gdacs.org}maplink {}
# {http://www.gdacs.org}gtsimage {}
# {http://www.gdacs.org}gtslink {}
# {http://www.gdacs.org}resources {}
# {http://www.gdacs.org}resource {'url': 'http://www.unitar.org/unosat/maps/USA', 'source': '', 'version': '0', 'type': 'html', 'id': 'UNOSATmaps_country'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/map?application=CYCLONES', 'source': 'JRC', 'version': '0', 'type': 'map', 'id': 'interactive_event_map'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/map?application=CYCLONES', 'source': 'JRC', 'version': '0', 'type': 'map', 'id': 'interactive_map'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.bom.gov.au/cyclone/index.shtml', 'source': 'BOM', 'version': '0', 'type': 'link', 'id': 'link_bom'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.usno.navy.mil/JTWC/', 'source': 'JTWC', 'version': '0', 'type': 'link', 'id': 'link_ptwc'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://weather.unisys.com/hurricane/atlantic/2018/index.php', 'source': '', 'version': '0', 'type': 'link', 'id': 'link_unisys_basin'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://earthobservatory.nasa.gov/Feeds/rss/nh.rss', 'source': 'NASA', 'version': '0', 'type': 'rss', 'id': 'nasa_earth_observatory'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.ssd.noaa.gov/PS/TROP/storms/FLORENCE.html', 'source': 'NOAA', 'version': '0', 'type': 'link', 'id': 'noaa_nesdis_event'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.reliefweb.int/updates/rss.xml?sl=environment-report_listing%252Ctaxonomy_index_tid_source-1503%252Ctaxonomy_index_tid_content_format-10%252Ctaxonomy_index_tid_disaster_type-4618', 'source': 'OCHA', 'version': '0', 'type': 'rss', 'id': 'ocha_sitrep'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/tc/1000495/clouds_1000495_60.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'overviewmap'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/tc/1000495/rain_1000495_60.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'rainmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.ssd.noaa.gov/PS/TROP/DATA/ETRAP/2018/Atlantic/FLORENCE/2018FLORENCE.pmqpf.09140900.00.GIF', 'source': 'NOAA', 'version': '0', 'type': 'image', 'id': 'rainmap_original'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/tc/1000495/1000495_60_tn.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'thumbnailmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://weather.unisys.com/hurricane/s_indian/2018/FLORENCE/track.gif', 'source': 'Unisys', 'version': '0', 'type': 'image', 'id': 'unisys_track'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/kml.aspx?profile=archive&eventid=1000495&eventtype=TC', 'source': 'JRC', 'version': '0', 'type': 'kml', 'id': 'kml_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/cap.aspx?profile=archive&eventid=1000495&eventtype=TC', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'cap_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.weather.gov', 'source': 'WMO', 'version': '0', 'type': 'link', 'id': 'metoffice'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/final/outres1.gif', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'storm_surge_animation'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/final/P1_MAXHEIGHT_END.jpg', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'storm_surge_maxheight'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/final/', 'source': 'JRC', 'version': '0', 'type': 'data', 'id': 'storm_surge_data'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/final/locations.kmz', 'source': 'JRC', 'version': '0', 'type': 'kmz', 'id': 'storm_surge_locations_affected_kmz'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/60/', 'source': 'JRC', 'version': '0', 'type': 'data', 'id': 'episode_data'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/', 'source': 'JRC', 'version': '0', 'type': 'data', 'id': 'impact_data'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/60/buffer74_all.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'latest_impact_hurricane'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/60/buffer39_all.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'latest_impact_storm'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/60/all_inpData.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'cyclone_timeline'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/TC/1000495/rss_1000495.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'event_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/TC/1000495/geojson_1000495_60.geojson', 'source': 'JRC', 'version': '0', 'type': 'geojson', 'id': 'event_geojson'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/TC/1000495/geojson_1000495_60.geojson', 'source': 'JRC', 'version': '0', 'type': 'json', 'id': 'jsonEvent'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/60/all_inpData.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'cyclone_timeline_HWRF'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/60/all_inpData.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'cyclone_timeline_GFS'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/tc/1000495/clouds_1000495_60_zoom.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'overviewmap_zoom'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': ' http://139.191.244.117/GNASystem/isochoice_iframe.aspx?iso3=USA&workflow=360&workflowgroup=INFORM2018', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_report'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.inform-index.org/', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_reference'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/final/locations.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'storm_surge_locations_affected'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000495_NOAA/final/locations.kmz', 'source': 'JRC', 'version': '0', 'type': 'kml', 'id': 'storm_surge_locations_affected_kml'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/TC/1000495/rss_1000495_60.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'episode_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://emergency.copernicus.eu/mapping/list-of-components/EMSR311/feed', 'source': 'EMSR', 'version': '1', 'type': 'rss', 'id': 'copernicusmap'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}resource {'url': 'http://emergency.copernicus.eu/mapping/list-of-components/EMSR311/', 'source': 'EMSR', 'version': '1', 'type': 'link', 'id': 'copernicuslink'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}identifiers {}
# item {}
# title {}
# description {}
# enclosure {'url': 'http://dma.gdacs.org/saved/gdacs/tc/1000499/1000499_28_tn.png', 'length': '1', 'type': 'image/png'}
# {http://www.gdacs.org}temporary {}
# link {}
# pubDate {}
# {http://www.gdacs.org}fromdate {}
# {http://www.gdacs.org}todate {}
# {http://www.gdacs.org}year {}
# {http://purl.org/dc/elements/1.1/}subject {}
# guid {'isPermaLink': 'false'}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}Point {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}lat {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}long {}
# {http://www.gdacs.org}bbox {}
# {http://www.georss.org/georss}point {}
# {http://www.gdacs.org}cap {}
# {http://www.gdacs.org}version {}
# {http://www.gdacs.org}eventtype {}
# {http://www.gdacs.org}alertlevel {}
# {http://www.gdacs.org}alertscore {}
# {http://www.gdacs.org}episodealertlevel {}
# {http://www.gdacs.org}episodealertscore {}
# {http://www.gdacs.org}eventname {}
# {http://www.gdacs.org}eventid {}
# {http://www.gdacs.org}episodeid {}
# {http://www.gdacs.org}calculationtype {}
# {http://www.gdacs.org}severity {'unit': 'km/h', 'value': '101.8512'}
# {http://www.gdacs.org}population {'unit': 'Pop74', 'value': '0'}
# {http://www.gdacs.org}vulnerability {'value': '1'}
# {http://www.gdacs.org}iso3 {}
# {http://www.gdacs.org}country {}
# {http://www.gdacs.org}glide {}
# {http://www.gdacs.org}mapimage {}
# {http://www.gdacs.org}maplink {}
# {http://www.gdacs.org}gtsimage {}
# {http://www.gdacs.org}gtslink {}
# {http://www.gdacs.org}resources {}
# {http://www.gdacs.org}resource {'url': 'http://www.unitar.org/unosat/maps/PRT', 'source': '', 'version': '0', 'type': 'html', 'id': 'UNOSATmaps_country'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/map?application=CYCLONES', 'source': 'JRC', 'version': '0', 'type': 'map', 'id': 'interactive_event_map'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/map?application=CYCLONES', 'source': 'JRC', 'version': '0', 'type': 'map', 'id': 'interactive_map'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.bom.gov.au/cyclone/index.shtml', 'source': 'BOM', 'version': '0', 'type': 'link', 'id': 'link_bom'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.usno.navy.mil/JTWC/', 'source': 'JTWC', 'version': '0', 'type': 'link', 'id': 'link_ptwc'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://weather.unisys.com/hurricane/atlantic/2018/index.php', 'source': '', 'version': '0', 'type': 'link', 'id': 'link_unisys_basin'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://earthobservatory.nasa.gov/Feeds/rss/nh.rss', 'source': 'NASA', 'version': '0', 'type': 'rss', 'id': 'nasa_earth_observatory'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.ssd.noaa.gov/PS/TROP/storms/HELENE.html', 'source': 'NOAA', 'version': '0', 'type': 'link', 'id': 'noaa_nesdis_event'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.reliefweb.int/updates/rss.xml?sl=environment-report_listing%252Ctaxonomy_index_tid_source-1503%252Ctaxonomy_index_tid_content_format-10%252Ctaxonomy_index_tid_disaster_type-4618', 'source': 'OCHA', 'version': '0', 'type': 'rss', 'id': 'ocha_sitrep'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/tc/1000499/clouds_1000499_28.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'overviewmap'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/tc/1000499/rain_1000499_28.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'rainmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.ssd.noaa.gov/PS/TROP/DATA/ETRAP/2018/Atlantic/HELENE/2018HELENE.pmqpf.09140900.00.GIF', 'source': 'NOAA', 'version': '0', 'type': 'image', 'id': 'rainmap_original'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/tc/1000499/1000499_28_tn.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'thumbnailmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://weather.unisys.com/hurricane/s_indian/2018/HELENE/track.gif', 'source': 'Unisys', 'version': '0', 'type': 'image', 'id': 'unisys_track'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/kml.aspx?profile=archive&eventid=1000499&eventtype=TC', 'source': 'JRC', 'version': '0', 'type': 'kml', 'id': 'kml_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/cap.aspx?profile=archive&eventid=1000499&eventtype=TC', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'cap_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.ipma.pt/pt/index.html', 'source': 'WMO', 'version': '0', 'type': 'link', 'id': 'metoffice'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/final/outres1.gif', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'storm_surge_animation'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/final/P1_MAXHEIGHT_END.jpg', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'storm_surge_maxheight'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/final/', 'source': 'JRC', 'version': '0', 'type': 'data', 'id': 'storm_surge_data'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/final/locations.kmz', 'source': 'JRC', 'version': '0', 'type': 'kmz', 'id': 'storm_surge_locations_affected_kmz'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/28/', 'source': 'JRC', 'version': '0', 'type': 'data', 'id': 'episode_data'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/', 'source': 'JRC', 'version': '0', 'type': 'data', 'id': 'impact_data'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/28/buffer74_all.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'latest_impact_hurricane'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/28/buffer39_all.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'latest_impact_storm'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/28/all_inpData.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'cyclone_timeline'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/TC/1000499/rss_1000499.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'event_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/TC/1000499/geojson_1000499_28.geojson', 'source': 'JRC', 'version': '0', 'type': 'geojson', 'id': 'event_geojson'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/TC/1000499/geojson_1000499_28.geojson', 'source': 'JRC', 'version': '0', 'type': 'json', 'id': 'jsonEvent'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/28/all_inpData.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'cyclone_timeline_HWRF'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/28/all_inpData.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'cyclone_timeline_GFS'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/tc/1000499/clouds_1000499_28_zoom.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'overviewmap_zoom'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': ' http://139.191.244.117/GNASystem/isochoice_iframe.aspx?iso3=PRT&workflow=360&workflowgroup=INFORM2018', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_report'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.inform-index.org/', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_reference'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/final/locations.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'storm_surge_locations_affected'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://webcritech.jrc.ec.europa.eu/ModellingCyclone/cyclonesurgeVM/1000499_NOAA/final/locations.kmz', 'source': 'JRC', 'version': '0', 'type': 'kml', 'id': 'storm_surge_locations_affected_kml'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/TC/1000499/rss_1000499_28.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'episode_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}identifiers {}
# item {}
# title {}
# description {}
# enclosure {'url': 'http://dma.gdacs.org/saved/gdacs/tc/1000500/1000500_27_tn.png', 'length': '1', 'type': 'image/png'}
# {http://www.gdacs.org}temporary {}
# link {}
# pubDate {}
# {http://www.gdacs.org}fromdate {}
# {http://www.gdacs.org}todate {}
# {http://www.gdacs.org}year {}
# {http://purl.org/dc/elements/1.1/}subject {}
# guid {'isPermaLink': 'false'}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}Point {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}lat {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}long {}
# {http://www.gdacs.org}bbox {}
# {http://www.georss.org/georss}point {}
# {http://www.gdacs.org}cap {}
# {http://www.gdacs.org}version {}
# {http://www.gdacs.org}eventtype {}
# {http://www.gdacs.org}alertlevel {}
# {http://www.gdacs.org}alertscore {}
# {http://www.gdacs.org}episodealertlevel {}
# {http://www.gdacs.org}episodealertscore {}
# {http://www.gdacs.org}eventname {}
# {http://www.gdacs.org}eventid {}
# {http://www.gdacs.org}episodeid {}
# {http://www.gdacs.org}calculationtype {}
# {http://www.gdacs.org}severity {'unit': 'km/h', 'value': '55.5552'}
# {http://www.gdacs.org}population {'unit': 'Pop74', 'value': '0'}
# {http://www.gdacs.org}vulnerability {'value': '3'}
# {http://www.gdacs.org}iso3 {}
# {http://www.gdacs.org}country {}
# {http://www.gdacs.org}glide {}
# {http://www.gdacs.org}mapimage {}
# {http://www.gdacs.org}maplink {}
# {http://www.gdacs.org}gtsimage {}
# {http://www.gdacs.org}gtslink {}
# {http://www.gdacs.org}resources {}
# {http://www.gdacs.org}resource {'url': 'http://www.unitar.org/unosat/maps/MSR', 'source': '', 'version': '0', 'type': 'html', 'id': 'UNOSATmaps_country'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/map?application=CYCLONES', 'source': 'JRC', 'version': '0', 'type': 'map', 'id': 'interactive_event_map'}
# ...
# {http://www.gdacs.org}gtsimage {}
# {http://www.gdacs.org}gtslink {}
# {http://www.gdacs.org}resources {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228184_2.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'overviewmap'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.unitar.org/unosat/maps/IRN', 'source': '', 'version': '0', 'type': 'html', 'id': 'UNOSATmaps_country'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/map?application=EARTHQUAKE&eventid=1156580&episodeid=1228184&coordinate=46.16,34.61', 'source': 'JRC', 'version': '0', 'type': 'map', 'id': 'interactive_event_map'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/calculation/EQ1_WPS/046\\eq_04615_03460.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'impact_xml'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.reliefweb.int/updates?sl=environment-report_listing%252Ctaxonomy_index_tid_source-1503%252Ctaxonomy_index_tid_content_format-10%252Ctaxonomy_index_tid_disaster_type-4628', 'source': 'OCHA', 'version': '0', 'type': 'rss', 'id': 'ocha_sitrep'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://cnt.rm.ingv.it/', 'source': 'INGV', 'version': '0', 'type': 'link', 'id': 'geooffice'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228184_1.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'thumbnailmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228184_4.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'populationmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.desinventar.net/DesInventar/profiletab.jsp?countrycode=ir', 'source': 'DesInventar', 'version': '0', 'type': 'link', 'id': 'desinventar_disasters_profile'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/calculation/EQ1_WPS/046/eq_04615_03460.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'impact_xml_old'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/gts_message/EQ/1156580/', 'source': 'JRC', 'version': '0', 'type': 'txt', 'id': 'gts_message_file'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/kml.aspx?profile=archive&eventid=1156580&eventtype=EQ', 'source': 'JRC', 'version': '0', 'type': 'kml', 'id': 'kml_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/cap.aspx?profile=archive&eventid=1156580&eventtype=EQ', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'cap_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.irimet.net', 'source': 'WMO', 'version': '0', 'type': 'link', 'id': 'metoffice'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156580/rss_1156580.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'event_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156580/geojson_1156580_1228184.geojson', 'source': 'JRC', 'version': '0', 'type': 'geojson', 'id': 'event_geojson'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156580/geojson_1156580_1228184.geojson', 'source': 'JRC', 'version': '0', 'type': 'json', 'id': 'jsonEvent'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': ' http://139.191.244.117/GNASystem/isochoice_iframe.aspx?iso3=IRN&workflow=360&workflowgroup=INFORM2018', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_report'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.inform-index.org/', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_reference'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/datareport/resources/EQ/1156580/alertbar_1156580_1228184.jpg', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'alertbar'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156580/rss_1156580_1228184.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'episode_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}identifiers {}
# {http://www.gdacs.org}identifier {'src': 'EMSC', 'id': 'emscid'}
# {http://www.gdacs.org}identifier {'src': 'JRC', 'id': 'eqcalculationpath'}
# {http://www.gdacs.org}identifier {'src': 'JRC', 'id': 'gdpcapita'}
# item {}
# title {}
# description {}
# enclosure {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228174_1.png', 'length': '1', 'type': 'image/png'}
# {http://www.gdacs.org}temporary {}
# link {}
# pubDate {}
# {http://www.gdacs.org}fromdate {}
# {http://www.gdacs.org}todate {}
# {http://www.gdacs.org}year {}
# {http://purl.org/dc/elements/1.1/}subject {}
# guid {'isPermaLink': 'false'}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}Point {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}lat {}
# {http://www.w3.org/2003/01/geo/wgs84_pos#}long {}
# {http://www.gdacs.org}bbox {}
# {http://www.georss.org/georss}point {}
# {http://www.gdacs.org}cap {}
# {http://www.gdacs.org}version {}
# {http://www.gdacs.org}eventtype {}
# {http://www.gdacs.org}alertlevel {}
# {http://www.gdacs.org}alertscore {}
# {http://www.gdacs.org}episodealertlevel {}
# {http://www.gdacs.org}episodealertscore {}
# {http://www.gdacs.org}eventname {}
# {http://www.gdacs.org}eventid {}
# {http://www.gdacs.org}episodeid {}
# {http://www.gdacs.org}calculationtype {}
# {http://www.gdacs.org}severity {'unit': 'M', 'value': '5'}
# {http://www.gdacs.org}population {'unit': 'Population in 100km', 'value': '26563'}
# {http://www.gdacs.org}vulnerability {'value': '1.62113293717696'}
# {http://www.gdacs.org}iso3 {}
# {http://www.gdacs.org}country {}
# {http://www.gdacs.org}glide {}
# {http://www.gdacs.org}mapimage {}
# {http://www.gdacs.org}maplink {}
# {http://www.gdacs.org}gtsimage {}
# {http://www.gdacs.org}gtslink {}
# {http://www.gdacs.org}resources {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228174_2.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'overviewmap'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.unitar.org/unosat/maps/IDN', 'source': '', 'version': '0', 'type': 'html', 'id': 'UNOSATmaps_country'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/map?application=EARTHQUAKE&eventid=1156579&episodeid=1228174&coordinate=128.1078,3.1954', 'source': 'JRC', 'version': '0', 'type': 'map', 'id': 'interactive_event_map'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/calculation/EQ1_WPS/128\\eq_12810_00320.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'impact_xml'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.reliefweb.int/updates?sl=environment-report_listing%252Ctaxonomy_index_tid_source-1503%252Ctaxonomy_index_tid_content_format-10%252Ctaxonomy_index_tid_disaster_type-4628', 'source': 'OCHA', 'version': '0', 'type': 'rss', 'id': 'ocha_sitrep'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://earthquake.usgs.gov/earthquakes/eventpage/us2000he1s#summary', 'source': 'NEIC', 'version': '0', 'type': 'html', 'id': 'neic_report'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://cnt.rm.ingv.it/', 'source': 'INGV', 'version': '0', 'type': 'link', 'id': 'geooffice'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228174_1.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'thumbnailmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/eq1228174_4.png', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'populationmap_cached'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.desinventar.net/DesInventar/profiletab.jsp?countrycode=id3', 'source': 'DesInventar', 'version': '0', 'type': 'link', 'id': 'desinventar_disasters_profile'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://earthquake.usgs.gov/earthquakes/eventpage/us2000he1s.json', 'source': 'NEIC', 'version': '0', 'type': 'json', 'id': 'neic_json'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/calculation/EQ1_WPS/128/eq_12810_00320.xml', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'impact_xml_old'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}xslt {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/gis/gts_message/EQ/1156579/', 'source': 'JRC', 'version': '0', 'type': 'txt', 'id': 'gts_message_file'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/kml.aspx?profile=archive&eventid=1156579&eventtype=EQ', 'source': 'JRC', 'version': '0', 'type': 'kml', 'id': 'kml_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/cap.aspx?profile=archive&eventid=1156579&eventtype=EQ', 'source': 'JRC', 'version': '0', 'type': 'xml', 'id': 'cap_link'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.bmkg.go.id', 'source': 'WMO', 'version': '0', 'type': 'link', 'id': 'metoffice'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156579/rss_1156579.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'event_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156579/geojson_1156579_1228174.geojson', 'source': 'JRC', 'version': '0', 'type': 'geojson', 'id': 'event_geojson'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156579/geojson_1156579_1228174.geojson', 'source': 'JRC', 'version': '0', 'type': 'json', 'id': 'jsonEvent'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156579_1228174__2.png', 'source': 'USGS', 'version': '0', 'type': 'image', 'id': 'shakemap_populationmap_static_v01'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://dma.gdacs.org/saved/gdacs/eq/sm/eq1156579_1228174__1.png', 'source': 'USGS', 'version': '0', 'type': 'image', 'id': 'shakemap_populationmap_overview_static_v01'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': ' http://139.191.244.117/GNASystem/isochoice_iframe.aspx?iso3=IDN&workflow=360&workflowgroup=INFORM2018', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_report'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.inform-index.org/', 'source': 'INFORM', 'version': '0', 'type': 'link', 'id': 'inform_reference'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org/datareport/resources/EQ/1156579/alertbar_1156579_1228174.jpg', 'source': 'JRC', 'version': '0', 'type': 'image', 'id': 'alertbar'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}resource {'url': 'http://www.gdacs.org//datareport/resources/EQ/1156579/rss_1156579_1228174.xml', 'source': 'JRC', 'version': '0', 'type': 'rss', 'id': 'episode_rss'}
# {http://www.gdacs.org}title {}
# {http://www.gdacs.org}description {}
# {http://www.gdacs.org}acknowledgements {}
# {http://www.gdacs.org}accesslevel {}
# {http://www.gdacs.org}identifiers {}
# {http://www.gdacs.org}identifier {'src': 'JRC', 'id': 'eqcalculationpath'}
# {http://www.gdacs.org}identifier {'src': 'JRC', 'id': 'gdpcapita'}
# {http://www.gdacs.org}identifier {'src': 'NEIC', 'id': 'neicid'}

# %%
from xml.dom import minidom
doc = minidom.parse(feed)

for count in doc.getElementsByTagName("guid"):
    print count.toxml()
# Out:
# <guid isPermaLink="false">EQ1156643</guid>
# <guid isPermaLink="false">EQ1156641</guid>
# <guid isPermaLink="false">TC1000495</guid>
# <guid isPermaLink="false">TC1000499</guid>
# <guid isPermaLink="false">TC1000500</guid>
# <guid isPermaLink="false">TC1000503</guid>
# <guid isPermaLink="false">EQ1156629</guid>
# <guid isPermaLink="false">TC1000498</guid>
# <guid isPermaLink="false">EQ1156619</guid>
# <guid isPermaLink="false">EQ1156614</guid>
# <guid isPermaLink="false">EQ1156609</guid>
# <guid isPermaLink="false">EQ1156605</guid>
# <guid isPermaLink="false">TC1000496</guid>
# <guid isPermaLink="false">EQ1156593</guid>
# <guid isPermaLink="false">EQ1156591</guid>
# <guid isPermaLink="false">TC1000502</guid>
# <guid isPermaLink="false">EQ1156583</guid>
# <guid isPermaLink="false">EQ1156580</guid>
# <guid isPermaLink="false">EQ1156579</guid>

# %%
for pubDate in root.iter('pubDate'):
    print pubDate.tag, pubDate.attrib
